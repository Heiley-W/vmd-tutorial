# %% [markdown]
# # Understanding the system
# - Diameter of channel opening: 26.24 A
# - Number of ions/ molecules
#   - Na+: 40
#   - Cl-: 40
#   - H2O: 2046![image.png](attachment:41ab1e32-0671-4af7-b215-b64a5dfce487.png)

# %% [markdown]
# # Simulation in electrolyte at 0 V
# - Duration: 1 ns
# - Timestep: 1 fs (Short-range non-bounded: 2 fs; Long-range non-bounded: 4 fs)
# - Fixed Atoms Constraint: cntwi_fix.pdb (Fix atoms with non-zero occupancy value)
# - Constant Pressure Control (Use NPT ensemble)
# - useConstantArea: yes (Membrane atoms are fixed)

# %%
# !cat cntwieq-01.conf
# Out:
# #############################################################
# ## JOB DESCRIPTION                                         ##
# #############################################################
#
# # Equilibration of nanotube system with ions.
# # 20 12
#
# #############################################################
# ## ADJUSTABLE PARAMETERS                                   ##
# #############################################################
#
# structure          cntwi.psf
# coordinates        cntwi.pdb
#
# set temperature    300
# set outputname     cntwieq-01
#
#
# # Continuing a job from the restart files
# #Bincoordinates     initial.coor
# #Binvelocities      initial.vel
#
#
# #############################################################
# ## SIMULATION PARAMETERS                                   ##
# #############################################################
#
# # Input
# paraTypeCharmm	    on
# parameters          par_all27_prot_lipid.prm
# temperature 	    $temperature
#
# ...

# %%
! namd3 cntwieq-01.conf > cntwieq-01.log
# Out:
# ^C

# %% [markdown]
# Slice accross X and Y axis
# <img src="attachment:4c476ca8-4866-4b09-a3cf-5cfedff1ed46.png" alt="Drawing" style="width: 500px;"/>
#
# Slice across Z axis
#
# <img src="attachment:1046467c-594e-48eb-991d-06b08223adfd.png" alt="Drawing" style="width: 500px;"/>
#
# Color bar for water
#
# <img src="attachment:dd300af6-3776-4a3a-a032-627a4b8982a8.png" alt="Drawing" style="width: 500px;"/>
#
# 0.028 atoms/A^3 = 4.65×10^4 mol/L, much higher than standard water concentration value 55 mol/L
#
# Color bar for cl
#
# <img src="attachment:8e7653d0-e816-4d3f-a4c5-24355e5bcfae.png" alt="Drawing" style="width: 500px;"/>
#
# Color bar for na
#
# <img src="attachment:35a9f147-09f3-48c9-8a41-906d7a5c60a1.png" alt="Drawing" style="width: 500px;"/>
#
# Electrostatic potential across Z axis (kT/e = 0.0258 Volts)
#
# <img src="attachment:5ab70791-52b4-4315-a68b-f9f83d405d56.png" alt="Drawing" style="width: 500px;"/>
#
# Variation 0.5 V

# %% [markdown]
# # With 1V Electric potential
#
# Water density in X and Y axis
#
# <img src="attachment:3a9a8a6a-1107-45c9-bfa0-9bdaa255d159.png" alt="Drawing" style="width: 500px;"/>
#
# Water density in Z axis
#
# <img src="attachment:f6263309-db4a-41ad-b10e-5b75f73e68eb.png" alt="Drawing" style="width: 500px;"/>
#
# Color bar for cl
#
# <img src="attachment:213ef650-c866-4709-a47a-c214f9ac6968.png" alt="Drawing" style="width: 500px;"/>
#
# Color bar for na
#
# <img src="attachment:a029135e-35a9-40d5-a479-e0072fc729b5.png" alt="Drawing" style="width: 500px;"/>
#
# Electrostatic potential
#
# <img src="attachment:a88549a0-f5c7-4db0-8a2d-c57bec49962c.png" alt="Drawing" style="width: 500px;"/>
#
# Variation 0.77 V

# %% [markdown]
# ## Current
#
# $$I=\frac{Nq}{\tau}$$

# %%
Script to compute ionic current
