# %% [markdown]
# # System info
#
# - Cation: Sodium (261)
# - Anion: Chloride (261)
# - Step: 0.05 ns
# - Run time: 500 ns
# - Number of frames: 10000

# %% [markdown]
# ## 1. Visualise the density of ions
#
# ### Steps:
# 1. Run the .tcl script below
# 4. Graphical representations settings
#     - Drawing method: VolumeSlice
#     - ColoringMethod: Volume
#     - Material: Transpatent
#     - Slice axis: X/Y/Z
# 6. Extensions > Color Scale Bar settings
#    - Autoscale: On
#    - Use molecule: .dx file
#    - Use representation: Volume

# %%
# !cat tcl/cldensity.tcl
# Out:
# set cl [atomselect top "name CLA"]
#
# volmap density $cl -allframes -combine avg -res 1 -o efcldens.dx
#
# mol load dx efcldens.dx

# %% [markdown]
# **Cl- (Vertical cross section)**
#
# ![image.png](attachment:212ff220-6eea-4e1d-9d90-281d8f8a6179.png)
#
# **Na+ (Vertical cross section)**
#
# ![image.png](attachment:1f9e656b-4848-4834-9b88-c80e100820fd.png)

# %% [markdown]
# ## 2. Calculate the current
#
# The following equation is used to estimate the current,
# $$I(t) = \frac{1}{\Delta t L_z} \sum_{i=1}^{N} q_i [z_i(t + \Delta t) - z_i(t)]$$
#
# which is implemented in the .tcl script below.

# %%
# Script to anaylse current by sodium ion
# !cat tcl/get-currSOD.tcl
# Out:
# proc mypermeation {frame} {
#   global out current_out current upperEnd lowerEnd wat IdList LabelList EntryList CoorList num1 num2 dt Lz
#   set oldLabelList $LabelList
#   set oldEntryList $EntryList
#   set oldCoorList $CoorList
#   set LabelList {}
#   set EntryList {}
#   set CoorList {}
#   set dt 5e-11
#   set Lz 20
#   set q 1.60217663e-19
#
# # 2 = Crossed upper end
# # -2 = Crossed lower end
# # -1 = Crossed lower end previously
# # 1 = Crossed upper end previously
#
#   foreach z [$wat get z] oldLab $oldLabelList id $IdList oldEntry $oldEntryList oldCoor $oldCoorList {
#     if {$z > $upperEnd} {
#       set newLab 2
#       set newEntry $frame
#       set newCoor $z
#       if {$oldLab == -1} {
#           incr num1
#           puts $out "wat $id permeated along +z direction at frame $frame in [expr $frame - $oldEntry] frames"
#           set current [expr {$current + 1/($dt*$Lz)*$q*($newCoor-$oldCoor)}]
#       }
#     } elseif {$z < $lowerEnd} {
#       set newLab -2
# ...

# %%
# Compare the original script and modified script
# !diff --color tcl/get-premSOD.tcl tcl/get-currSOD.tcl
# Out:
# 1,2d0
# <
# <
# 4c2
# <   global out upperEnd lowerEnd wat IdList LabelList EntryList num1 num2
# ---
# >   global out current_out current upperEnd lowerEnd wat IdList LabelList EntryList CoorList num1 num2 dt Lz
# 6a5
# >   set oldCoorList $CoorList
# 8a8,16
# >   set CoorList {}
# >   set dt 5e-11
# >   set Lz 20
# >   set q 1.60217663e-19
# >
# > # 2 = Crossed upper end
# > # -2 = Crossed lower end
# > # -1 = Crossed lower end previously
# > # 1 = Crossed upper end previously
# 10c18
# <   foreach z [$wat get z] oldLab $oldLabelList id $IdList oldEntry $oldEntryList {
# ---
# >   foreach z [$wat get z] oldLab $oldLabelList id $IdList oldEntry $oldEntryList oldCoor $oldCoorList {
# 13a22
# >       set newCoor $z
# 16a26
# >           set current [expr {$current + 1/($dt*$Lz)*$q*($newCoor-$oldCoor)}]
# 20a31
# >       set newCoor $z
# 23a35
# >           set current [expr {$current + 1/($dt*$Lz)*$q*($newCoor-$oldCoor)}]
# 27a40,41
# >       set newCoor $z
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the data from the first file
data1 = np.loadtxt('dat-output/run1/currentSOD-10.dat')
time1 = data1[:, 0]
current1 = data1[:, 1]

# Load the data from the second file
data2 = np.loadtxt('dat-output/run1/currentCLA-10.dat')
time2 = data2[:, 0]
current2 = data2[:, 1]

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(time1, current1, label='Na+ current', color='b')
plt.plot(time2, current2, label='Cl- current', color='r')
plt.xlabel('Step')
plt.ylabel('Accumulated Current (A)')
plt.title('Accumulated Current Over Steps (Run 1)')
plt.grid()
plt.legend()
plt.tight_layout()
plt.savefig('dat-output/run1/combined_accumulated_current_plot.png')
plt.show()

# %%
# !cat dat-output/run1/overallCLA-10.dat
# !cat dat-output/run1/overallSOD-10.dat

# %%
# Load the data from the first file
data1 = np.loadtxt('dat-output/run2/currentSOD-10.dat')
time1 = data1[:, 0]
current1 = data1[:, 1]

# Load the data from the second file
data2 = np.loadtxt('dat-output/run2/currentCLA-10.dat')
time2 = data2[:, 0]
current2 = data2[:, 1]

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(time1, current1, label='Na+ current', color='b')
plt.plot(time2, current2, label='Cl- current', color='r')
plt.xlabel('Step')
plt.ylabel('Accumulated Current (A)')
plt.title('Accumulated Current Over Steps (Run 2)')
plt.grid()
plt.legend()
plt.tight_layout()
plt.savefig('dat-output/run2/combined_accumulated_current_plot.png')
plt.show()

# %%
# !cat dat-output/run2/overallCLA-10.dat
# !cat dat-output/run2/overallSOD-10.dat
# Out:
# 0 CLA crossed along +z direction
# 379 CLA crossed along -z direction
# 35 SOD crossed along +z direction
# 0 SOD crossed along -z direction
